# %%
from bs4 import BeautifulSoup
import requests

# %%
url = "https://www.w3resource.com/"

# %%
response = requests.get(url)

# %%
response
# Out:
# <Response [200]>

# %%
data = response.text

# %%
data
# Out:
# '\ufeff<!DOCTYPE html>\n\n<html lang="en">\n<head>\n\n<meta charset="utf-8">\n<link type="text/css" rel="stylesheet" href="/assets/mdl/material.min.css">\n<link type="text/css" rel="stylesheet" href="/assets/mdl/additional.css">\n<meta name="viewport" content="width=device-width, initial-scale=1.0">\n<link rel="shortcut icon" href="//www.w3resource.com/images/favicon.png">\n<title>Web development tutorials | w3resource</title>\n<meta name="viewport" content="width=device-width, initial-scale=1.0">\n<meta name="description" content="Web development tutorials on HTML, CSS, JS, PHP, SQL, MySQL, PostgreSQL, MongoDb, JSON and more.">\n<meta property="og:title" content="web development tutorials from w3resource" />\n<meta property="og:description" content="Web development tutorials on HTML, CSS, JS, PHP, SQL, MySQL, PostgreSQL, MOngoDb, JSON and more." />\n<meta property="og:type" content="tutorial" />\n<meta property="og:url" content="https://www.w3resource.com/" />\n<meta property="og:image" content="https://www.w3resource.com/images/w3resource-logo.png" />\n<meta property="og:site_name" content="w3resource" />\n<meta name="msvalidate.01" content="1F8E3A7A751C0BD17BCB6CE7509D800B" />\n\n<script type="application/ld+json">\r\n{\r\n  "@context": "https://schema.org",\r\n  "@type": "WebSite",\r\n  "url": "https://www.w3resource.com/",\r\n  "potentialAction": {\r\n    "@type": "SearchAction",\r\n    "target": "https://query.w3resource.com/search?q=w3resource",\r\n    "query-input": "required name=w3resource"\r\n  }\r\n}\r\n</script>\n<script src="//cdnjs.cloudflare.com/ajax/libs/cookieconsent2/1.0.9/cookieconsent.min.js"></script>\n<script>\r\n\r\nwindow.cookieconsent_options = {\r\n\r\nmessage: \'This site uses cookies to deliver our services and to show you relevant ads. By using our site, you acknowledge that you have read and understood our Privacy Policy. Your use of w3resource Services, is subject to these policies\',\r\n\r\ntheme:\'dark-bottom\',\r\n\r\nlearnMore: \'More info\',\r\n\r\nlink: \'https://www.w3resource.com/privacy.php\'\r\n\r\n};\r\n\r\n</script>\n<style type="text/css">\r\n.demo-card-square.mdl-card {\r\n  width: 320px;\r\n  height: 320px;\r\n}\r\n.demo-card-square > .mdl-card__title {\r\n  color: #fff;\r\n /* background:\r\n    url(\'../assets/demos/dog.png\') bottom right 15% no-repeat #46B6AC;*/\r\n}\r\n.mdl-card__supporting-text a {\r\ndisplay: inline-block;\r\npadding: 5px;\r\n}\r\n.mdl-card__supporting-text a:link {\r\ncolor: #4485FF\r\n}\r\n.mdl-card__supporting-text a:hover {\r\ncolor: #f86d1d\r\n}\r\n.mdl-card__supporting-text a:visited {\r\ncolor: #5407bf\r\n}\r\n.mdl-card__supporting-text a:active {\r\ncolor: #4485FF\r\n}\r\n.mdl-card__actions.mdl-card--border {\r\nbackground-color: #4485FF\r\n}\r\n.demo-card-square.mdl-card {\r\nheight: 250px\r\n}\r\n.mdl-card__actions.mdl-card--border a{\r\ncolor: #fff\r\n}\r\nhtml,body {\r\nbackground-color: #e8e8ee\r\n}\r\n</style>\n</head>\n<body>\n<style type="text/css">\narticle a {\ntext-decoration: none\t\n}\n.mdl-menu {\nmin-width: 1024px;\t\n}\n.mdl-menu__item {\nheight: 24px;\nline-height: 24px\t\n}\n.header_notice a{\ncolor: #fff\n}\n</style>\n<script>\n  (function(i,s,o,g,r,a,m){i[\'GoogleAnalyticsObject\']=r;i[r]=i[r]||function(){\n  (i[r].q=i[r].q||[]).push(arguments)},i[r].l=1*new Date();a=s.createElement(o),\n  m=s.getElementsByTagName(o)[0];a.async=1;a.src=g;m.parentNode.insertBefore(a,m)\n  })(window,document,\'script\',\'//www.google-analytics.com/analytics.js\',\'ga\');\n\n  ga(\'create\', \'UA-21234995-1\', \'auto\');\n  ga(\'send\', \'pageview\');\n</script>\n<div class="mdl-layout mdl-layout--fixed-header">\n<header class="mdl-layout__header">\n<div class="mdl-layout__header-row">\n<a href="https://www.w3resource.com" style="text-decoration: none;"><span class="mdl-layout-title" style="margin-left: -50px;margin-top: -5px;color:#fff">w3resource</span></a>\n\n<button id="main-menu-lower-right" class="mdl-button mdl-js-button mdl-button--icon">\n< ...

# %%
soup = BeautifulSoup(data, 'html.parser')

# %%
tags = soup.find_all('a')

# %%
for tag in tags:
    print(tag.get
# Out:
# https://www.w3resource.com
# https://www.w3resource.com/html/HTML-tutorials.php
# https://www.w3resource.com/css/CSS-tutorials.php
# https://www.w3resource.com/javascript/javascript.php
# https://www.w3resource.com/html5/introduction.php
# https://www.w3resource.com/schema.org/introduction.php
# https://www.w3resource.com/phpjs/use-php-functions-in-javascript.php
# https://www.w3resource.com/twitter-bootstrap/tutorial.php
# https://www.w3resource.com/responsive-web-design/overview.php
# https://www.w3resource.com/zurb-foundation3/introduction.php
# https://www.w3resource.com/pure/
# https://www.w3resource.com/html5-canvas/
# https://www.w3resource.com/course/javascript-course.html
# https://www.w3resource.com/icon/
# https://www.w3resource.com/linux-system-administration/installation.php
# https://www.w3resource.com/linux-system-administration/linux-commands-introduction.php
# https://www.w3resource.com/linux-system-administration/installation.php
# https://www.w3resource.com/php/php-home.php
# https://www.w3resource.com/python/python-tutorial.php
# https://www.w3resource.com/java-tutorial/
# https://www.w3resource.com/node.js/node.js-tutorials.php
# https://www.w3resource.com/ruby/
# https://www.w3resource.com/c-programming/programming-in-c.php
# https://www.w3resource.com/sql/tutorials.php
# https://www.w3resource.com/mysql/mysql-tutorials.php
# https://w3resource.com/PostgreSQL/tutorial.php
# https://www.w3resource.com/sqlite/
# https://www.w3resource.com/mongodb/nosql.php
# https://www.w3resource.com/mongodb/nosql.php
# https://www.w3resource.com/API/google-plus/tutorial.php
# https://www.w3resource.com/API/youtube/tutorial.php
# https://www.w3resource.com/API/google-maps/index.php
# https://www.w3resource.com/API/flickr/tutorial.php
# https://www.w3resource.com/API/last.fm/tutorial.php
# https://www.w3resource.com/API/twitter-rest-api/
# https://www.w3resource.com/xml/xml.php
# https://www.w3resource.com/JSON/introduction.php
# https://www.w3resource.com/ajax/introduction.php
# https://www.w3resource.com/html-css-exercise/index.php
# https://www.w3resource.com/javascript-exercises/
# https://www.w3resource.com/jquery-exercises/
# https://www.w3resource.com/jquery-ui-exercises/
# https://www.w3resource.com/coffeescript-exercises/
# https://www.w3resource.com/php-exercises/
# https://www.w3resource.com/python-exercises/
# https://www.w3resource.com/c-programming-exercises/
# https://www.w3resource.com/csharp-exercises/
# https://www.w3resource.com/java-exercises/
# https://www.w3resource.com/sql-exercises/
# https://www.w3resource.com/oracle-exercises/
# https://www.w3resource.com/mysql-exercises/
# https://www.w3resource.com/sqlite-exercises/
# https://www.w3resource.com/postgresql-exercises/
# https://www.w3resource.com/mongodb-exercises/
# https://www.w3resource.com/twitter-bootstrap/examples.php
# https://www.w3resource.com/euler-project/
# https://w3resource.com/w3skills/html5-quiz/
# https://w3resource.com/w3skills/php-fundamentals/
# https://w3resource.com/w3skills/sql-beginner/
# https://w3resource.com/w3skills/python-beginner-quiz/
# https://w3resource.com/w3skills/mysql-basic-quiz/
# https://w3resource.com/w3skills/javascript-basic-skill-test/
# https://w3resource.com/w3skills/javascript-advanced-quiz/
# https://w3resource.com/w3skills/javascript-quiz-part-iii/
# https://w3resource.com/w3skills/mongodb-basic-quiz/
# https://www.w3resource.com/form-template/
# https://www.w3resource.com/slides/
# https://www.w3resource.com/form-template/
# https://www.w3resource.com/slides/
# https://www.w3resource.com/convert/number/binary-to-decimal.php
# https://www.w3resource.com/excel/
# https://www.w3resource.com/video-tutorial/php/some-basics-of-php.php
# https://www.w3resource.com/video-tutorial/javascript/list-of-tutorial.php
# https://www.w3resource.com/web-development-tools/firebug-tutorials.php
# https://www.w3resource.com/web-development-tools/useful-web-development-tools.php
# https://www.facebook.com/w3resource
# https://twitter.com/w3resource
# https://plus.google.com/+W3resource
# https://in.linkedin.com/in/w3resource
# https://feeds.feedburner.com/W3resource
# //www.w3resource.com
# None
# https://www.w3resource.com/html/HTML-tutorials.php
# https://www.w3resource.com/css/CSS-tutorials.php
# https://www.w3resource.com/javascript/javascript.php
# https://www.w3resource.com/html5/introduction.php
# https://www.w3resource.com/schema.org/introduction.php
# https://www.w3resource.com/phpjs/use-php-functions-in-javascript.php
# https://www.w3resource.com/twitter-bootstrap/tutorial.php
# https://www.w3resource.com/responsive-web-design/overview.php
# https://www.w3resource.com/zurb-foundation3/introduction.php
# https://www.w3resource.com/pure/
# https://www.w3resource.com/html5-canvas/
# https://www.w3resource.com/course/javascript-course.html
# https://www.w3resource.com/icon/
# https://www.w3resource.com/angular/getting-started-with-angular.php
# https://www.w3resource.com/react/react-js-overview.php
# https://www.w3resource.com/vue/installation.php
# https://www.w3resource.com/jest/jest-getting-started.php
# None
# https://www.w3resource.com/php/php-home.php
# https://www.w3resource.com/python/python-tutorial.php
# https://www.w3resource.com/numpy/index.php
# https://www.w3resource.com/pandas/index.php
# https://www.w3resource.com/java-tutorial/
# https://www.w3resource.com/node.js/node.js-tutorials.php
# https://www.w3resource.com/ruby/
# https://www.w3resource.com/c-programming/programming-in-c.php
# https://www.w3resource.com/php/composer/a-gentle-introduction-to-composer.php
# https://www.w3resource.com/php/PHPUnit/a-gentle-introduction-to-unit-test-and-testing.php
# https://www.w3resource.com/laravel/laravel-tutorial.php
# None
# https://www.w3resource.com/sql/tutorials.php
# https://www.w3resource.com/mysql/mysql-tutorials.php
# https://w3resource.com/PostgreSQL/tutorial.php
# https://www.w3resource.com/sqlite/
# https://www.w3resource.com/mongodb/nosql.php
# https://www.w3resource.com/mongodb/nosql.php
# https://www.w3resource.com/oracle/index.php
# https://www.w3resource.com/redis/index.php
# None
# https://www.w3resource.com/html-css-exercise/index.php
# https://www.w3resource.com/javascript-exercises/
# https://www.w3resource.com/jquery-exercises/
# https://www.w3resource.com/jquery-ui-exercises/
# https://www.w3resource.com/coffeescript-exercises/
# https://www.w3resource.com/php-exercises/
# https://www.w3resource.com/python-exercises/
# https://www.w3resource.com/python-exercises/numpy/index.php
# https://www.w3resource.com/python-exercises/pandas/index.php
# https://www.w3resource.com//machine-learning/scikit-learn/iris/index.php
# https://www.w3resource.com/ruby-exercises/
# https://www.w3resource.com/graphics/matplotlib/
# https://www.w3resource.com/c-programming-exercises/
# https://www.w3resource.com/csharp-exercises/
# https://www.w3resource.com/cpp-exercises/
# https://www.w3resource.com/java-exercises/
# https://www.w3resource.com/r-programming-exercises/
# https://w3resource.com/swift-programming-exercises/
# https://www.w3resource.com/sql-exercises/
# https://www.w3resource.com/oracle-exercises/
# https://w3resource.com/plsql-exercises/
# https://www.w3resource.com/mysql-exercises/
# https://www.w3resource.com/sqlite-exercises/
# https://www.w3resource.com/postgresql-exercises/
# https://www.w3resource.com/mongodb-exercises/
# https://www.w3resource.com/twitter-bootstrap/examples.php
# https://www.w3resource.com/euler-project/
# None
# https://www.w3resource.com/linux-system-administration/installation.php
# https://www.w3resource.com/linux-system-administration/linux-commands-introduction.php
# https://www.w3resource.com/linux-system-administration/installation.php
# https://www.w3resource.com/xml/xml.php
# https://www.w3resource.com/JSON/introduction.php
# https://www.w3resource.com/ajax/introduction.php
# https://www.w3resource.com/API/google-plus/tutorial.php
# https://www.w3resource.com/API/youtube/tutorial.php
# https://www.w3resource.com/API/google-maps/index.php
# https://www.w3resource.com/API/flickr/tutorial.php
# https://www.w3resource.com/API/last.fm/tutorial.php
# https://www.w3resource.com/API/twitter-rest-api/
# None
# https://www.w3resource.com/excel/
# https://www.w3resource.com/web-development-tools/firebug-tutorials.php
# https://www.w3resource.com/web-development-tools/useful-web-development-tools.php
# https://www.w3resource.com/form-template/
# https://www.w3resource.com/slides/
# https://www.w3resource.com/convert/number/binary-to-decimal.php
# None
# https://w3resource.com/w3skills/
# https://w3resource.com/w3skills/
# https://w3resource.com/w3skills/
# https://w3resource.com/w3skills/
# https://w3resource.com/w3skills/
# https://w3resource.com/w3skills/
# https://w3resource.com/w3skills/
# https://w3resource.com/w3skills/
# https://w3resource.com/w3skills/
# https://www.w3resource.com/c-programming-exercises/basic-declarations-and-expressions/c-programming-basic-exercises-81.php
# https://www.w3resource.com/c-programming-exercises/basic-declarations-and-expressions/c-programming-basic-exercises-80.php
# https://www.w3resource.com/c-programming-exercises/basic-declarations-and-expressions/c-programming-basic-exercises-75.php
# https://www.w3resource.com/c-programming-exercises/basic-declarations-and-expressions/c-programming-basic-exercises-82.php
# https://www.w3resource.com/c-programming-exercises/basic-declarations-and-expressions/c-programming-basic-exercises-76.php
# https://www.w3resource.com/c-programming-exercises/basic-declarations-and-expressions/c-programming-basic-exercises-83.php
# https://www.w3resource.com/c-programming-exercises/basic-declarations-and-expressions/c-programming-basic-exercises-73.php
# https://www.w3resource.com/machine-learning/scikit-learn/iris/python-machine-learning-scikit-learn-iris-basic-exercise-3.php
# https://www.w3resource.com/machine-learning/scikit-learn/iris/python-machine-learning-k-nearest-neighbors-algorithm-exercise-8.php
# https://www.w3resource.com/machine-learning/scikit-learn/iris/python-machine-learning-scikit-learn-iris-basic-exercise-2.php
# https://www.w3resource.com/machine-learning/scikit-learn/iris/python-machine-learning-scikit-learn-iris-visualization-exercise-19.php
# https://www.w3resource.com/machine-learning/scikit-learn/iris/python-machine-learning-scikit-learn-iris-visualization-exercise-17.php
# https://www.w3resource.com/machine-learning/scikit-learn/iris/python-machine-learning-scikit-learn-iris-basic-exercise-4.php
# https://www.w3resource.com/machine-learning/scikit-learn/iris/python-machine-learning-scikit-learn-iris-visualization-exercise-10.php
# https://www.w3resource.com/machine-learning/scikit-learn/iris/python-machine-learning-scikit-learn-logistic-regression-exercise-1.php
# https://www.w3resource.com/machine-learning/scikit-learn/iris/python-machine-learning-scikit-learn-iris-visualization-exercise-4.php
# https://www.w3resource.com/machine-learning/scikit-learn/iris/python-machine-learning-scikit-learn-iris-basic-exercise-1.php
# https://www.w3resource.com/machine-learning/scikit-learn/iris/python-machine-learning-scikit-learn-iris-visualization-exercise-6.php
# https://www.w3resource.com/machine-learning/scikit-learn/iris/python-machine-learning-k-nearest-neighbors-algorithm-exercise-5.php
# https://www.w3resource.com/machine-learning/scikit-learn/iris/python-machine-learning-k-nearest-neighbors-algorithm-exercise-4.php
# https://www.w3resource.com/machine-learning/scikit-learn/iris/python-machine-learning-scikit-learn-iris-basic-exercise-6.php
# https://www.w3resource.com/machine-learning/scikit-learn/iris/python-machine-learning-scikit-learn-iris-visualization-exercise-18.php
# https://www.w3resource.com/machine-learning/scikit-learn/iris/python-machine-learning-scikit-learn-iris-visualization-exercise-11.php
# https://www.w3resource.com/machine-learning/scikit-learn/iris/python-machine-learning-scikit-learn-iris-visualization-exercise-3.php
# https://www.w3resource.com/machine-learning/scikit-learn/iris/python-machine-learning-scikit-learn-logistic-regression-exercise-3.php
# https://www.w3resource.com/machine-learning/scikit-learn/iris/python-machine-learning-scikit-learn-iris-visualization-exercise-1.php
# https://www.w3resource.com/machine-learning/scikit-learn/iris/python-machine-learning-k-nearest-neighbors-algorithm-exercise-7.php
# https://www.w3resource.com/machine-learning/scikit-learn/iris/python-machine-learning-k-nearest-neighbors-algorithm-exercise-3.php
# https://www.w3resource.com/machine-learning/scikit-learn/iris/python-machine-learning-scikit-learn-iris-visualization-exercise-15.php
# https://www.w3resource.com/machine-learning/scikit-learn/iris/python-machine-learning-scikit-learn-iris-visualization-exercise-8.php
# https://www.w3resource.com/machine-learning/scikit-learn/iris/python-machine-learning-scikit-learn-iris-visualization-exercise-12.php
# https://www.w3resource.com/machine-learning/scikit-learn/iris/python-machine-learning-scikit-learn-iris-basic-exercise-7.php
# https://www.w3resource.com/machine-learning/scikit-learn/iris/python-machine-learning-k-nearest-neighbors-algorithm-exercise-2.php
# https://www.w3resource.com/machine-learning/scikit-learn/iris/python-machine-learning-k-nearest-neighbors-algorithm-exercise-6.php
# https://www.w3resource.com/machine-learning/scikit-learn/iris/python-machine-learning-scikit-learn-iris-basic-exercise-8.php
# https://www.w3resource.com/machine-learning/scikit-learn/iris/index.php
# https://www.w3resource.com/machine-learning/scikit-learn/iris/python-machine-learning-scikit-learn-iris-basic-exercise-5.php
# https://www.w3resource.com/machine-learning/scikit-learn/iris/python-machine-learning-scikit-learn-iris-visualization-exercise-2.php
# https://www.w3resource.com/machine-learning/scikit-learn/iris/python-machine-learning-k-nearest-neighbors-algorithm-exercise-1.php
# https://www.w3resource.com/machine-learning/scikit-learn/iris/python-machine-learning-scikit-learn-iris-visualization-exercise-13.php
# https://www.w3resource.com/machine-learning/scikit-learn/iris/python-machine-learning-scikit-learn-logistic-regression-exercise-2.php
# https://www.w3resource.com/machine-learning/scikit-learn/iris/python-machine-learning-scikit-learn-iris-visualization-exercise-7.php
# https://www.w3resource.com/machine-learning/scikit-learn/iris/python-machine-learning-scikit-learn-iris-visualization-exercise-5.php
# https://www.w3resource.com/machine-learning/scikit-learn/iris/python-machine-learning-scikit-learn-iris-visualization-exercise-14.php
# https://www.w3resource.com/machine-learning/scikit-learn/iris/python-machine-learning-scikit-learn-iris-visualization-exercise-9.php
# https://www.w3resource.com/machine-learning/scikit-learn/iris/python-machine-learning-scikit-learn-iris-visualization-exercise-16.php
# https://www.w3resource.com/java-exercises/basic/java-basic-exercise-246.php
# https://www.w3resource.com/java-exercises/basic/java-basic-exercise-247.php
# https://www.w3resource.com/java-exercises/basic/java-basic-exercise-245.php
# https://www.w3resource.com/java-exercises/basic/java-basic-exercise-244.php
# https://www.w3resource.com/jest/mock-functions.php
# https://www.w3resource.com/jest/migrating-to-jest.php
# https://www.w3resource.com/jest/es6-class-mocks.php
# https://www.w3resource.com/jest/snapshot-testing.php
# https://www.w3resource.com/jest/using-with-mongodb.php
# https://www.w3resource.com/jest/setup-and-teardown.php
# https://www.w3resource.com/jest/bypassing-module-mocks.php
# https://www.w3resource.com/jest/dom-manipulation.php
# https://www.w3resource.com/jest/using-with-dynamobd.php
# https://www.w3resource.com/jest/an-async-example.php
# https://www.w3resource.com/jest/testing-asynchronous-code.php
# https://www.w3resource.com/jest/using-matchers.php
# https://www.w3resource.com/jest/watch-plugins.php
# https://www.w3resource.com/jest/using-with-webpack.php
# https://www.w3resource.com/jest/timer-mocks.php
# https://www.w3resource.com/jest/introduction.php
# https://www.w3resource.com/jest/manual-mocks.php
# https://www.w3resource.com/jest/jest-getting-started.php
# https://www.w3resource.com/jest/using-with-puppeteer.php
# https://www.w3resource.com/jest/jest-platform.php
# https://www.w3resource.com/csharp-exercises/data-types/csharp-data-type-exercise-2.php
# https://www.w3resource.com/csharp-exercises/data-types/csharp-data-type-exercise-3.php
# https://www.w3resource.com/csharp-exercises/data-types/csharp-data-type-exercise-7.php
# https://www.w3resource.com/csharp-exercises/data-types/csharp-data-type-exercise-9.php
# https://www.w3resource.com/csharp-exercises/data-types/csharp-data-type-exercise-1.php
# https://www.w3resource.com/csharp-exercises/data-types/csharp-data-type-exercise-6.php
# https://www.w3resource.com/csharp-exercises/data-types/csharp-data-type-exercise-4.php
# https://www.w3resource.com/csharp-exercises/linq/csharp-linq-exercise-9.php
# https://www.w3resource.com/csharp-exercises/linq/csharp-linq-exercise-5.php
# https://www.w3resource.com/csharp-exercises/linq/csharp-linq-exercise-17.php
# https://www.w3resource.com/csharp-exercises/linq/csharp-linq-exercise-11.php
# https://www.w3resource.com/csharp-exercises/linq/csharp-linq-exercise-20.php
# https://www.w3resource.com/csharp-exercises/linq/csharp-linq-exercise-12.php
# https://www.w3resource.com/csharp-exercises/linq/csharp-linq-exercise-15.php
# https://www.w3resource.com/csharp-exercises/linq/csharp-linq-exercise-22.php
# https://www.w3resource.com/csharp-exercises/linq/csharp-linq-exercise-23.php
# https://www.w3resource.com/csharp-exercises/linq/csharp-linq-exercise-4.php
# https://www.w3resource.com/csharp-exercises/linq/csharp-linq-exercise-29.php
# https://www.w3resource.com/csharp-exercises/linq/csharp-linq-exercise-8.php
# https://www.w3resource.com/csharp-exercises/linq/csharp-linq-exercise-28.php
# https://www.w3resource.com/csharp-exercises/linq/csharp-linq-exercise-18.php
# https://www.w3resource.com/csharp-exercises/linq/csharp-linq-exercise-6.php
# https://www.w3resource.com/csharp-exercises/linq/csharp-linq-exercise-3.php
# https://www.w3resource.com/csharp-exercises/linq/csharp-linq-exercise-7.php
# https://www.w3resource.com/csharp-exercises/linq/csharp-linq-exercise-21.php
# https://www.w3resource.com/csharp-exercises/linq/csharp-linq-exercise-13.php
# https://www.w3resource.com/csharp-exercises/linq/csharp-linq-exercise-19.php
# https://www.w3resource.com/csharp-exercises/linq/csharp-linq-exercise-10.php
# https://creativecommons.org/licenses/by-nc-sa/3.0/deed.en_US
# https://www.w3resource.com/privacy.php
# https://www.w3resource.com/about.php
# https://www.w3resource.com/contact.php
# https://www.w3resource.com/feedback.php
# https://www.w3resource.com/advertise.php

# %%
titles = soup.find_all('a')

# %%
for title in titles:
    print(title.text)
# Out:
# w3resource
# HTML
# CSS
# JavaScript
# HTML5
# Schema.org
# php.js
# Twitter Bootstrap
# Responsive Web Design tutorial
# Zurb Foundation 3 tutorials
# Pure CSS
# HTML5 Canvas
# JavaScript Course
# Icon
# Linux Home
# Linux Commands
# Linux Server Administration
# PHP
# Python
# Java
# Node.js
# Ruby
# C programming
# SQL(2003 standard of ANSI)
# MySQL
# PostgreSQL
# SQLite
# NoSQL
# MongoDB
# Google Plus API
# Youtube API
# Google Maps API
# Flickr API
# Last.fm API
# Twitter REST API
# XML
# JSON
# Ajax
# HTML CSS Exercises
# JavaScript Exercises
# jQuery Exercises
# jQuery-UI Exercises
# CoffeeScript Exercises
# PHP Exercises
# Python Exercises
# C Programming Exercises
# C# Sharp Exercises
# Java Exercises
# SQL Exercises
# Oracle Exercises
# MySQL Exercises
# SQLite Exercises
# PostgreSQL Exercises
# MongoDB Exercises
# Twitter Bootstrap Examples
# Euler Project
# HTML5 Quiz
# PHP Quiz
# SQL Quiz
# Python Quiz
# MySQL Quiz
# JavaScript I Quiz
# JavaScript II Quiz
# JavaScript III Quiz
# MongoDB Quiz
# Forms Template
# Slides Presentation
# Forms Template
# Slide Presentation
# Number Conversion
# Excel 2013 tutorial
# PHP Videos
# JavaScript Videos
# Firebug Tutorial
# Useful Tools
# Facebook
# Twitter
# Google Plus
# Linkedin
# RSS
#
# Frontend tutorials
# HTML
# CSS
# JavaScript
# HTML5
# Schema.org
# php.js
# Twitter Bootstrap
# Responsive Web Design tutorial
# Zurb Foundation 3 tutorials
# Pure CSS
# HTML5 Canvas
# JavaScript Course
# Icon
# Angular
# React
# Vue
# Jest
# Backend tutorials
# PHP
# Python
# Python-NumPy
# Python-Pandas
# Java
# Node.js
# Ruby
# C programming
# Composer
# PHPUnit
# Laravel
# Database tutorials
# SQL(2003 standard of ANSI)
# MySQL
# PostgreSQL
# SQLite
# NoSQL
# MongoDB
# Oracle
# Redis
# Exercises with online editor
# HTML CSS
# JavaScript
# jQuery
# jQuery-UI
# CoffeeScript
# PHP
# Python
# NumPy
# Pandas
# Machine Learning
# Ruby
# Matplotlib
# C Programming
# C# Sharp
# C++
# Java
# R programming
# Swift
# SQL
# Oracle
# PL/SQL
# MySQL
# SQLite
# PostgreSQL
# MongoDB
# Twitter Bootstrap Examples
# Euler Project
# Linux, Data interchange & API tutorials
# Linux Home
# Linux Commands
# Linux Server Administration
# XML
# JSON
# Ajax
# Google Plus API
# Youtube API
# Google Maps API
# Flickr API
# Last.fm API
# Twitter REST API
# Miscellaneous Tutorials
# Excel Tutorial
# Firebug Tutorial
# Useful Tools
# Google Docs Forms Template
# Google Docs Slides Presentation
# Number Conversion
# Quizzes
# HTML5
# PHP
# SQL
# Python
# MySQL
# JavaScript I
# JavaScript II
# JavaScript III
# MongoDB
# C Exercises: Reads the side of a square and prints a hollow square using hash (#) character
# C Exercises: Reads the side of a square and prints square using hash (#) character
# C Exercises: Accepts one seven-digit number and separates the number into its individual digits, and prints the digits separated from one another by two spaces each
# C Exercises: Reads in a five-digit integer and determines whether or not it’s a palindrome
# C Exercises: Calculate and prints the squares and cubes of the numbers from 0 to 20
# C Exercises: Reads an integer and count number of 3s in the given number
# C Exercises: Reads in two integers and check whether the first integer is a multiple of the second integer
# Python Scikit learn: Get the number of observations, missing values and nan values
# Python Scikit-learn: K Nearest Neighbors - Create a plot of k values vs accuracy
# Python Scikit learn: Print the keys, number of rows-columns, feature names and the description of the Iris data
# Python Scikit-learn: Create a Principal component analysis of iris dataset
# Python Scikit-learn: Create a hitmap using Seaborn to present their relations
# Python Scikit learn: Create a 2-D array with ones on the diagonal and zeros elsewhere
# Python Scikit-learn: Create a joinplot and add regression and kernel density fits using “reg” to describe individual distributions on the same plot between Sepal length and Sepal width
# Python Scikit-learn: Create some basic statistical details like percentile, mean etc
# Python Scikit-learn: Create a graph to find relationship between the sepal length and width
# Python Scikit learn: Print the shape of the data, type of the data and first 3 rows
# Python Scikit-learn: Create a graph to see how the length and width of SepalLength, SepalWidth, PetalLength, PetalWidth are distributed
# Python Scikit-learn: K Nearest Neighbors - Calculate the accuracy of the model using the K Nearest Neighbor Algorithm
# Python Scikit-learn: K Nearest Neighbors - Split the iris dataset into 70% train data and 30% test data
# Python Scikit learn: Get observations of each species from iris data
# Python Scikit-learn: Create a box plot which shows the distribution of quantitative data in a way that facilitates comparisons between variables or across levels of a categorical variable of iris dataset
# Python Scikit-learn: Draw a scatterplot, then add a joint density estimate to describe individual distributions on the same plot between Sepal length and Sepal width
# Python Scikit-learn: Create a Pie plot to get the frequency of the three species of the Iris data
# Python Scikit-learn: Get the accuracy of the Logistic Regression
# Python Scikit-learn: Create a plot to get a general Statistics of Iris data
# Python Scikit-learn: K Nearest Neighbors - Create a plot to present the performance for different values of k
# Python Scikit-learn: K Nearest Neighbors - Convert Species columns in a numerical column of the iris dataframe
# Python Scikit-learn: Create a kde plot of petal_length versus petal width for setosa species of flower
# Python Scikit-learn: Create a joinplot to describe individual distributions on the same plot between Sepal length and Sepal width
# Python Scikit-learn: Create a joinplot using “kde” to describe individual distributions on the same plot between Sepal length and Sepal width and use ‘+’ sign as marker
# Python Scikit learn: Drop Id column from a given Dataframe and print the modified part
# Python Scikit-learn: K Nearest Neighbors - Split the iris dataset into 70% train data and 30% test data
# Python Scikit-learn: K Nearest Neighbors - Calculate the performance for different values of k
# Python Scikit learn: Access first four cells from a given Dataframe using the index and column labels
# Python: Machine learning - Scikit-learn Exercises, Practice, Solution
# Python Scikit learn: View basic statistical details like percentile, mean, std etc. of iris data
# Python Scikit-learn: Create a Bar plot to get the frequency of the three species of the Iris data
# Python Scikit-learn: K Nearest Neighbors - Split the iris dataset into its attributes (X) and labels (y)
# Python Scikit-learn: Create a pairplot of the iris data set and check which flower species seems to be the most separable
# Python Scikit-learn: Create a scatter plot using sepal length and petal_width to separate the Species classes
# Python Scikit-learn: Create a joinplot to describe individual distributions on the same plot between Sepal length and Sepal width
# Python Scikit-learn: Create a graph to find relationship between the petal length and width
# Python Scikit-learn: Create a kde plot of sepal_length versus sepal width for setosa species of flower
# Python Scikit-learn: Create a joinplot using “kde” to describe individual distributions on the same plot between Sepal length and Sepal width
# Python Scikit-learn: Create a kde plot of two shaded bivariate densities of Sepal Width and Sepal Length
# Java Exercises: Convert 3 digits positive number in given format
# Java Exercises: Accepts three integers and check whether sum of the first two given integers is greater than third one
# Java Exercises: Accepts students name, id, and marks and display the highest score and the lowest score
# Java Exercises: Accepts a string from the user and check whether the string is correct or not
# Mock Functions
# Migrating to Jest
# ES6 Class Mocks
# Snapshot Testing
# Using Jest with MongoDB and DynamoDB
# Setup and Teardown
# Bypassing module mocks
# DOM Manipulation
# Using with DynamoDB
# An Async Example
# Testing Asynchronous Code
# Using Matchers
# Watch Plugins
# Using with webpack
# Timer Mocks
# Jest
# Manual Mocks
# Jest Getting Started
# Using with puppeteer
# Jest Platform
# C# Sharp Exercises: Display a triangle
# C# Sharp Exercises: Test a password
# C# Sharp Exercises: Calculate the speed in kilometers and miles per hour from distance and time
# C# Sharp Exercises: Check a input is a vowel, a digit, or any other symbol
# C# Sharp Exercises: Display three letters in reverse order
# C# Sharp Exercises: Program to display certain values of the function
# C# Sharp Exercises: Perform an operation on +, -, *, x, / and displays the result of that operation
# C# Sharp Exercises: Create a list of numbers and display the numbers greater than 80
# C# Sharp Exercises: Display the characters and frequency of character from giving string
# C# Sharp Exercises: Remove Items from List using remove function
# C# Sharp Exercises: Display top nth records from the list
# C# Sharp Exercises: Remove Items from List by passing the item index
# C# Sharp Exercises: Find the uppercase words in a string
# C# Sharp Exercises: Count File Extensions and Group it
# C# Sharp Exercises: Find the strings for a specific minimum length
# C# Sharp Exercises: Generate a Cartesian Product of two sets
# C# Sharp Exercises: Display the number and frequency of number from given array
# C# Sharp Exercises: Split a collection of strings into some groups
# C# Sharp Exercises: Find the string which starts and ends with a specific character
# C# Sharp Exercises: Display the list according to the length then by name in ascending order
# C# Sharp Exercises: Remove Items from List by creating object internally by filtering
# C# Sharp Exercises: Display the name of the days of a week
# C# Sharp Exercises: Find the number and its square of an array which is more than 20
# C# Sharp Exercises: Display numbers, number*frequency and the frequency
# C# Sharp Exercises: Remove range of items from list by passing start index and number of elements to delete
# C# Sharp Exercises: Convert a string array to a string
# C# Sharp Exercises: Remove Items from List by passing filters
# C# Sharp Exercises: Accept the members of a list and display the members more than a specific value
# This work is licensed under a Creative Commons Attribution-NonCommercial-ShareAlike 3.0 Unported License.
# Privacy
# About
# Contact
# Feedback
# Advertise
